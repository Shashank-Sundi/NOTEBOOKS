# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### IMPORTING THE DATASET

# %%
data=pd.read_csv(r'C:\Users\Shashank Sundi\Desktop\I neuron\assignments\INSURANCE FRAUD CLASSIFICATION\insurance_claim_fraud.csv')
pd.set_option("display.max_columns",40)
data
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0      250/500               1000                1406.91               0
# 1      250/500               2000                1197.22         5000000
# 2      100/300               2000                1413.14         5000000
# 3      250/500               2000                1415.74         6000000
# 4     500/1000               1000                1583.91         6000000
# ..         ...                ...                    ...             ...
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip insured_sex insured_education_level insured_occupation  \
# 0         466132        MALE                      MD       craft-repair
# 1         468176        MALE                      MD  machine-op-inspct
# 2         430632      FEMALE                     PhD              sales
# 3         608117      FEMALE                     PhD       armed-forces
# 4         610706        MALE               Associate              sales
# ..           ...         ...                     ...                ...
# 995       431289      FEMALE                 Masters       craft-repair
# 996       608177      FEMALE                     PhD     prof-specialty
# 997       442797      FEMALE                 Masters       armed-forces
# 998       441714        MALE               Associate  handlers-cleaners
# 999       612260      FEMALE               Associate              sales
#
#     insured_hobbies insured_relationship  capital-gains  capital-loss  \
# 0          sleeping              husband          53300             0
# 1           reading       other-relative              0             0
# 2       board-games            own-child          35100             0
# 3       board-games            unmarried          48900        -62400
# 4       board-games            unmarried          66000        -46000
# ..              ...                  ...            ...           ...
# 995       paintball            unmarried              0             0
# 996        sleeping                 wife          70900             0
# 997  bungie-jumping       other-relative          35100             0
# 998    base-jumping                 wife              0             0
# 999        kayaking              husband              0             0
#
#     incident_date             incident_type   collision_type  \
# 0      2015-01-25  Single Vehicle Collision   Side Collision
# 1      2015-01-21             Vehicle Theft                ?
# 2      2015-02-22   Multi-vehicle Collision   Rear Collision
# 3      2015-01-10  Single Vehicle Collision  Front Collision
# 4      2015-02-17             Vehicle Theft                ?
# ..            ...                       ...              ...
# 995    2015-02-22  Single Vehicle Collision  Front Collision
# 996    2015-01-24  Single Vehicle Collision   Rear Collision
# 997    2015-01-23   Multi-vehicle Collision   Side Collision
# 998    2015-02-26  Single Vehicle Collision   Rear Collision
# 999    2015-02-26                Parked Car                ?
#
#     incident_severity authorities_contacted incident_state incident_city  \
# 0        Major Damage                Police             SC      Columbus
# 1        Minor Damage                Police             VA     Riverwood
# 2        Minor Damage                Police             NY      Columbus
# 3        Major Damage                Police             OH     Arlington
# 4        Minor Damage                  None             NY     Arlington
# ..                ...                   ...            ...           ...
# 995      Minor Damage                  Fire             NC    Northbrook
# 996      Major Damage                  Fire             SC     Northbend
# 997      Minor Damage                Police             NC     Arlington
# 998      Major Damage                 Other             NY     Arlington
# 999      Minor Damage                Police             WV      Columbus
#
#        incident_location  incident_hour_of_the_day  \
# 0         9935 4th Drive                         5
# 1           6608 MLK Hwy                         8
# 2      7121 Francis Lane                         7
# 3       6956 Maple Drive                         5
# 4           3041 3rd Ave                        20
# ..                   ...                       ...
# 995   6045 Andromedia St                        20
# 996     3092 Texas Drive                        23
# 997          7629 5th St                         4
# 998        6128 Elm Lane                         2
# 999  1416 Cherokee Ridge                         6
#
#      number_of_vehicles_involved property_damage  bodily_injuries  witnesses  \
# 0                              1             YES                1          2
# 1                              1               ?                0          0
# 2                              3              NO                2          3
# 3                              1               ?                1          2
# 4                              1              NO                0          1
# ..                           ...             ...              ...        ...
# 995                            1             YES                0          1
# 996                            1             YES                2          3
# 997                            3               ?                2          3
# 998                            1               ?                0          1
# 999                            1               ?                0          3
#
#     police_report_available  total_claim_amount  injury_claim  property_claim  \
# 0                       YES               71610          6510           13020
# 1                         ?                5070           780             780
# 2                        NO               34650          7700            3850
# 3                        NO               63400          6340            6340
# 4                        NO                6500          1300             650
# ..                      ...                 ...           ...             ...
# 995                       ?               87200         17440            8720
# 996                       ?              108480         18080           18080
# 997                     YES               67500          7500            7500
# 998                     YES               46980          5220            5220
# 999                       ?                5060           460             920
#
#      vehicle_claim   auto_make auto_model  auto_year fraud_reported  _c39
# 0            52080        Saab        92x       2004              Y   NaN
# 1             3510    Mercedes       E400       2007              Y   NaN
# 2            23100       Dodge        RAM       2007              N   NaN
# 3            50720   Chevrolet      Tahoe       2014              Y   NaN
# 4             4550      Accura        RSX       2009              N   NaN
# ..             ...         ...        ...        ...            ...   ...
# 995          61040       Honda     Accord       2006              N   NaN
# 996          72320  Volkswagen     Passat       2015              N   NaN
# 997          52500      Suburu    Impreza       1996              N   NaN
# 998          36540        Audi         A5       1998              N   NaN
# 999           3680    Mercedes       E400       2007              N   NaN
#
# [1000 rows x 40 columns]

# %% [markdown]
# ### DATA DESCRIPTION
#
# Features:
#
# 1.	months_as_customer: It denotes the number of months for which the customer is associated with the insurance company.
# 2.	age: continuous. It denotes the age of the person.
# 3.	policy_number: The policy number.
# 4.	policy_bind_date: Start date of the policy.
# 5.	policy_state: The state where the policy is registered.
# 6.	policy_csl-combined single limits. How much of the bodily injury will be covered from the total damage.
# https://www.berkshireinsuranceservices.com/arecombinedsinglelimitsbetter
# 7.	policy_deductable: The amount paid out of pocket by the policy-holder before an insurance provider will pay any expenses.
# 8.	policy_annual_premium: The yearly premium for the policy.
# 9.	umbrella_limit: An umbrella insurance policy is extra liability insurance coverage that goes beyond the limits of the insured's homeowners, auto or watercraft insurance. It provides an additional layer of security to those who are at risk of being sued for damages to other people's property or injuries caused to others in an accident.
# 10.	insured_zip: The zip code where the policy is registered.
# 11.	insured_sex: It denotes the person's gender.
# 12.	insured_education_level: The highest educational qualification of the policy-holder.
# 13.	insured_occupation: The occupation of the policy-holder.
# 14.	insured_hobbies: The hobbies of the policy-holder.
# 15.	insured_relationship: Dependents on the policy-holder.
# 16.	capital-gain: It denotes the monitory gains by the person.
# 17.	capital-loss: It denotes the monitory loss by the person.
# 18.	incident_date: The date when the incident happened.
# 19.	incident_type: The type of the incident.
# 20.	collision_type: The type of collision that took place.
# 21.	incident_severity: The severity of the incident.
# 22.	authorities_contacted: Which authority was contacted.
# 23.	incident_state: The state in which the incident took place.
# 24.	incident_city: The city in which the incident took place.
# 25.	incident_location: The street in which the incident took place.
# 26.	incident_hour_of_the_day: The time of the day when the incident took place.
# 27.	property_damage: If any property damage was done.
# 28.	bodily_injuries: Number of bodily injuries.
# 29.	Witnesses: Number of witnesses present.
# 30.	police_report_available: Is the police report available.
# 31.	total_claim_amount: Total amount claimed by the customer.
# 32.	injury_claim: Amount claimed for injury
# 33.	property_claim: Amount claimed for property damage.
# 34.	vehicle_claim: Amount claimed for vehicle damage.
# 35.	auto_make: The manufacturer of the vehicle
# 36.	auto_model: The model of the vehicle.
# 37.	auto_year: The year of manufacture of the vehicle.
#
#
# Target Label:
# Whether the claim is fraudulent or not.
# 38.	fraud_reported:  Y or N

# %%
data.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', '_c39'],
#       dtype='object')

# %% [markdown]
# ### CHECKING AND VALIDATING DTYPES

# %%
data.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# 0       466132        MALE                      MD       craft-repair
# 1       468176        MALE                      MD  machine-op-inspct
# 2       430632      FEMALE                     PhD              sales
# 3       608117      FEMALE                     PhD       armed-forces
# 4       610706        MALE               Associate              sales
#
#   insured_hobbies insured_relationship  capital-gains  capital-loss  \
# 0        sleeping              husband          53300             0
# 1         reading       other-relative              0             0
# 2     board-games            own-child          35100             0
# 3     board-games            unmarried          48900        -62400
# 4     board-games            unmarried          66000        -46000
#
#   incident_date             incident_type   collision_type incident_severity  \
# 0    2015-01-25  Single Vehicle Collision   Side Collision      Major Damage
# 1    2015-01-21             Vehicle Theft                ?      Minor Damage
# 2    2015-02-22   Multi-vehicle Collision   Rear Collision      Minor Damage
# 3    2015-01-10  Single Vehicle Collision  Front Collision      Major Damage
# 4    2015-02-17             Vehicle Theft                ?      Minor Damage
#
#   authorities_contacted incident_state incident_city  incident_location  \
# 0                Police             SC      Columbus     9935 4th Drive
# 1                Police             VA     Riverwood       6608 MLK Hwy
# 2                Police             NY      Columbus  7121 Francis Lane
# 3                Police             OH     Arlington   6956 Maple Drive
# 4                  None             NY     Arlington       3041 3rd Ave
#
#    incident_hour_of_the_day  number_of_vehicles_involved property_damage  \
# 0                         5                            1             YES
# 1                         8                            1               ?
# 2                         7                            3              NO
# 3                         5                            1               ?
# 4                        20                            1              NO
#
#    bodily_injuries  witnesses police_report_available  total_claim_amount  \
# 0                1          2                     YES               71610
# 1                0          0                       ?                5070
# 2                2          3                      NO               34650
# 3                1          2                      NO               63400
# 4                0          1                      NO                6500
#
#    injury_claim  property_claim  vehicle_claim  auto_make auto_model  \
# 0          6510           13020          52080       Saab        92x
# 1           780             780           3510   Mercedes       E400
# 2          7700            3850          23100      Dodge        RAM
# 3          6340            6340          50720  Chevrolet      Tahoe
# 4          1300             650           4550     Accura        RSX
#
#    auto_year fraud_reported  _c39
# 0       2004              Y   NaN
# 1       2007              Y   NaN
# 2       2007              N   NaN
# 3       2014              Y   NaN
# 4       2009              N   NaN

# %%
pd.DataFrame(data=data.dtypes.values,index=data.dtypes.index).T
# Out:
#   months_as_customer    age policy_number policy_bind_date policy_state  \
# 0              int64  int64         int64           object       object
#
#   policy_csl policy_deductable policy_annual_premium umbrella_limit  \
# 0     object             int64               float64          int64
#
#   insured_zip insured_sex insured_education_level insured_occupation  \
# 0       int64      object                  object             object
#
#   insured_hobbies insured_relationship capital-gains capital-loss  \
# 0          object               object         int64        int64
#
#   incident_date incident_type collision_type incident_severity  \
# 0        object        object         object            object
#
#   authorities_contacted incident_state incident_city incident_location  \
# 0                object         object        object            object
#
#   incident_hour_of_the_day number_of_vehicles_involved property_damage  \
# 0                    int64                       int64          object
#
#   bodily_injuries witnesses police_report_available total_claim_amount  \
# 0           int64     int64                  object              int64
#
#   injury_claim property_claim vehicle_claim auto_make auto_model auto_year  \
# 0        int64          int64         int64    object     object     int64
#
#   fraud_reported     _c39
# 0         object  float64

# %%
# we can observe that-

# Following features should be of type datetime , but are identified as object or numeric
# policy_bind_date , incident_date , auto_year

# We convert them to datetime cuz , We want to create new features from them , instead of dropping them off------Features will be created later on
# claim_duration = policy_bind_date -incident_date ---- then remove the two columns from data , but keep them during html form input
# car_duration = auto_year - incident_date  --- then remove the two columns from data , but keep them during html form input

data.auto_year=pd.to_datetime(data.auto_year,format="%Y")
data.policy_bind_date=pd.to_datetime(data.policy_bind_date)
data.incident_date=pd.to_datetime(data.incident_date)

# Remove following columns-
# _c39 -- contains all nan values , so drop them
# insured_zip, policy_number , incident_location ---- Since all the values are unique and can be unique for every person , 
#                                                    they don't provide any information ; so, we'll drop these features

data=data.drop(['insured_zip', 'policy_number' , 'incident_location', '_c39'],axis=1)

# %%
print(data.shape)
pd.DataFrame(data=data.dtypes.values,index=data.dtypes.index).T
# Out:
# (1000, 36)
#   months_as_customer    age policy_bind_date policy_state policy_csl  \
# 0              int64  int64   datetime64[ns]       object     object
#
#   policy_deductable policy_annual_premium umbrella_limit insured_sex  \
# 0             int64               float64          int64      object
#
#   insured_education_level insured_occupation insured_hobbies  \
# 0                  object             object          object
#
#   insured_relationship capital-gains capital-loss   incident_date  \
# 0               object         int64        int64  datetime64[ns]
#
#   incident_type collision_type incident_severity authorities_contacted  \
# 0        object         object            object                object
#
#   incident_state incident_city incident_hour_of_the_day  \
# 0         object        object                    int64
#
#   number_of_vehicles_involved property_damage bodily_injuries witnesses  \
# 0                       int64          object           int64     int64
#
#   police_report_available total_claim_amount injury_claim property_claim  \
# 0                  object              int64        int64          int64
#
#   vehicle_claim auto_make auto_model       auto_year fraud_reported
# 0         int64    object     object  datetime64[ns]         object

# %% [markdown]
# ### DESCRIPTIVE STATISTICS

# %%
# collecting index of numerical columns
Int=data.dtypes[data.dtypes=='int64'].index
Float=data.dtypes[data.dtypes=='float64'].index
num_index=Int.append(Float)

# collecting index of categorical columns
categ_index=data.dtypes[data.dtypes=='object'].index

# collecting index of datetime columns
date_index=data.dtypes[data.dtypes=='datetime64[ns]'].index

# %%
data[num_index].describe()
# Out:
#        months_as_customer          age  policy_deductable  umbrella_limit  \
# count         1000.000000  1000.000000        1000.000000    1.000000e+03
# mean           203.954000    38.948000        1136.000000    1.101000e+06
# std            115.113174     9.140287         611.864673    2.297407e+06
# min              0.000000    19.000000         500.000000   -1.000000e+06
# 25%            115.750000    32.000000         500.000000    0.000000e+00
# 50%            199.500000    38.000000        1000.000000    0.000000e+00
# 75%            276.250000    44.000000        2000.000000    0.000000e+00
# max            479.000000    64.000000        2000.000000    1.000000e+07
#
#        capital-gains   capital-loss  incident_hour_of_the_day  \
# count    1000.000000    1000.000000               1000.000000
# mean    25126.100000  -26793.700000                 11.644000
# std     27872.187708   28104.096686                  6.951373
# min         0.000000 -111100.000000                  0.000000
# 25%         0.000000  -51500.000000                  6.000000
# 50%         0.000000  -23250.000000                 12.000000
# 75%     51025.000000       0.000000                 17.000000
# max    100500.000000       0.000000                 23.000000
#
#        number_of_vehicles_involved  bodily_injuries    witnesses  \
# count                   1000.00000      1000.000000  1000.000000
# mean                       1.83900         0.992000     1.487000
# std                        1.01888         0.820127     1.111335
# min                        1.00000         0.000000     0.000000
# 25%                        1.00000         0.000000     1.000000
# 50%                        1.00000         1.000000     1.000000
# 75%                        3.00000         2.000000     2.000000
# max                        4.00000         2.000000     3.000000
#
#        total_claim_amount  injury_claim  property_claim  vehicle_claim  \
# count          1000.00000   1000.000000     1000.000000    1000.000000
# mean          52761.94000   7433.420000     7399.570000   37928.950000
# std           26401.53319   4880.951853     4824.726179   18886.252893
# min             100.00000      0.000000        0.000000      70.000000
# 25%           41812.50000   4295.000000     4445.000000   30292.500000
# 50%           58055.00000   6775.000000     6750.000000   42100.000000
# 75%           70592.50000  11305.000000    10885.000000   50822.500000
# max          114920.00000  21450.000000    23670.000000   79560.000000
#
#        policy_annual_premium
# count            1000.000000
# mean             1256.406150
# std               244.167395
# min               433.330000
# 25%              1089.607500
# 50%              1257.200000
# 75%              1415.695000
# max              2047.590000

# %%
data[categ_index].describe()
# Out:
#        policy_state policy_csl insured_sex insured_education_level  \
# count          1000       1000        1000                    1000
# unique            3          3           2                       7
# top              OH    250/500      FEMALE                      JD
# freq            352        351         537                     161
#
#        insured_occupation insured_hobbies insured_relationship  \
# count                1000            1000                 1000
# unique                 14              20                    6
# top     machine-op-inspct         reading            own-child
# freq                   93              64                  183
#
#                   incident_type  collision_type incident_severity  \
# count                      1000            1000              1000
# unique                        4               4                 4
# top     Multi-vehicle Collision  Rear Collision      Minor Damage
# freq                        419             292               354
#
#        authorities_contacted incident_state incident_city property_damage  \
# count                   1000           1000          1000            1000
# unique                     5              7             7               3
# top                   Police             NY   Springfield               ?
# freq                     292            262           157             360
#
#        police_report_available auto_make auto_model fraud_reported
# count                     1000      1000       1000           1000
# unique                       3        14         39              2
# top                         NO     Dodge        RAM              N
# freq                       343        80         43            753

# %%
data[date_index].describe()
# Out:
#            policy_bind_date        incident_date            auto_year
# count                  1000                 1000                 1000
# unique                  951                   60                   21
# top     1992-04-28 00:00:00  2015-02-02 00:00:00  1995-01-01 00:00:00
# freq                      3                   28                   56
# first   1990-01-08 00:00:00  2015-01-01 00:00:00  1995-01-01 00:00:00
# last    2015-02-22 00:00:00  2015-03-01 00:00:00  2015-01-01 00:00:00

# %% [markdown]
# ### DATA CLEANING & NULL VALUE IMPUTATION

# %%
pd.DataFrame(data=data.isnull().sum().values,index=data.isnull().sum().index).T
# Out:
#    months_as_customer  age  policy_bind_date  policy_state  policy_csl  \
# 0                   0    0                 0             0           0
#
#    policy_deductable  policy_annual_premium  umbrella_limit  insured_sex  \
# 0                  0                      0               0            0
#
#    insured_education_level  insured_occupation  insured_hobbies  \
# 0                        0                   0                0
#
#    insured_relationship  capital-gains  capital-loss  incident_date  \
# 0                     0              0             0              0
#
#    incident_type  collision_type  incident_severity  authorities_contacted  \
# 0              0               0                  0                      0
#
#    incident_state  incident_city  incident_hour_of_the_day  \
# 0               0              0                         0
#
#    number_of_vehicles_involved  property_damage  bodily_injuries  witnesses  \
# 0                            0                0                0          0
#
#    police_report_available  total_claim_amount  injury_claim  property_claim  \
# 0                        0                   0             0               0
#
#    vehicle_claim  auto_make  auto_model  auto_year  fraud_reported
# 0              0          0           0          0               0

# %%
# in above cell, no null values are displayed , cuz the nan values are in the form of an invalid type - ?

data=data.replace('?',np.nan)
pd.DataFrame(data=data.isnull().sum().values,index=data.isnull().sum().index).T
# Out:
#    months_as_customer  age  policy_bind_date  policy_state  policy_csl  \
# 0                   0    0                 0             0           0
#
#    policy_deductable  policy_annual_premium  umbrella_limit  insured_sex  \
# 0                  0                      0               0            0
#
#    insured_education_level  insured_occupation  insured_hobbies  \
# 0                        0                   0                0
#
#    insured_relationship  capital-gains  capital-loss  incident_date  \
# 0                     0              0             0              0
#
#    incident_type  collision_type  incident_severity  authorities_contacted  \
# 0              0             178                  0                      0
#
#    incident_state  incident_city  incident_hour_of_the_day  \
# 0               0              0                         0
#
#    number_of_vehicles_involved  property_damage  bodily_injuries  witnesses  \
# 0                            0              360                0          0
#
#    police_report_available  total_claim_amount  injury_claim  property_claim  \
# 0                      343                   0             0               0
#
#    vehicle_claim  auto_make  auto_model  auto_year  fraud_reported
# 0              0          0           0          0               0

# %%
# getting columns with null values

null_val_cols=data.isnull().sum()[data.isnull().sum()>0].index
null_val_cols
# Out:
# Index(['collision_type', 'property_damage', 'police_report_available'], dtype='object')

# %%
for i in null_val_cols:
    print(data[i].value_counts().head(10))
# Out:
# Rear Collision     292
# Side Collision     276
# Front Collision    254
# Name: collision_type, dtype: int64
# NO     338
# YES    302
# Name: property_damage, dtype: int64
# NO     343
# YES    314
# Name: police_report_available, dtype: int64

# %%
data['collision_type'].isnull().sum()
# Out:
# 178

# %%
# Performing Random Sample Imputation for the above columns 

for col in null_val_cols:
    rand_samples=data[col].dropna().sample(n=data[col].isnull().sum())
    rand_samples.index=data[col][data[col].isnull()].index
    data.loc[rand_samples.index,col]=rand_samples

# %%
# All the null values have been imputed 

pd.DataFrame(data=data.isnull().sum().values,index=data.isnull().sum().index).T
# Out:
#    months_as_customer  age  policy_bind_date  policy_state  policy_csl  \
# 0                   0    0                 0             0           0
#
#    policy_deductable  policy_annual_premium  umbrella_limit  insured_sex  \
# 0                  0                      0               0            0
#
#    insured_education_level  insured_occupation  insured_hobbies  \
# 0                        0                   0                0
#
#    insured_relationship  capital-gains  capital-loss  incident_date  \
# 0                     0              0             0              0
#
#    incident_type  collision_type  incident_severity  authorities_contacted  \
# 0              0               0                  0                      0
#
#    incident_state  incident_city  incident_hour_of_the_day  \
# 0               0              0                         0
#
#    number_of_vehicles_involved  property_damage  bodily_injuries  witnesses  \
# 0                            0                0                0          0
#
#    police_report_available  total_claim_amount  injury_claim  property_claim  \
# 0                        0                   0             0               0
#
#    vehicle_claim  auto_make  auto_model  auto_year  fraud_reported
# 0              0          0           0          0               0

# %% [markdown]
# ### Data Visualization

# %%
import joypy
from pandas import plotting
from pandas.plotting import parallel_coordinates

import plotly
import plotly.offline as py
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go
from plotly import tools
import plotly.figure_factory as ff
init_notebook_mode(connected = True)

import plotly.figure_factory as ff
from bubbly.bubbly import bubbleplot
import plotly_express as px
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Checking Distribution of numerical columns

fig,ax=plt.subplots(5,3,figsize=(20,15))

i,j=0,0
for col in num_index:
    sns.distplot(data[col],ax=ax[i,j])
    j+=1
    if j==3:
        i+=1
        j=0

fig.tight_layout()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning:
#
# Default bandwidth for data is 0; skipping density estimation.

# %%
# Checking Normality of numerical columns

from scipy import stats

fig,ax=plt.subplots(5,3,figsize=(20,15))

i,j=0,0
for col in num_index:
    stats.probplot(data[col],plot=ax[i,j])
    ax[i,j].set_title(col)
    j+=1
    if j==3:
        i+=1
        j=0

fig.tight_layout()

# %%
fig = px.scatter(data, x = 'total_claim_amount', y = 'policy_annual_premium', color = 'fraud_reported', marginal_y = 'histogram')
fig.show()
# Out:
# <div>                            <div id="75ff81f7-8d1c-4e0e-86af-dfd7bfd1de05" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75ff81f7-8d1c-4e0e-86af-dfd7bfd1de05")) {                    Plotly.newPlot(                        "75ff81f7-8d1c-4e0e-86af-dfd7bfd1de05",                        [{"hovertemplate": "fraud_reported=Y<br>total_claim_amount=%{x}<br>policy_annual_premium=%{y}<extra></extra>", "legendgroup": "Y", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Y", "orientation": "v", "showlegend": true, "type": "scatter", "x": [71610, 5070, 63400, 64100, 46200, 63120, 71520, 98160, 71500, 5720, 67140, 53100, 60200, 60170, 97080, 62800, 69480, 68520, 59130, 82320, 89700, 68310, 61290, 72200, 60940, 45120, 98340, 72930, 64890, 79800, 70590, 60940, 70000, 47700, 70400, 76560, 55440, 63840, 44730, 69200, 70800, 99320, 64000, 71680, 112320, 63570, 54240, 37280, 107900, 71280, 53600, 81840, 88660, 73920, 5300, 59800, 53460, 81360, 81070, 70290, 61380, 47630, 53600, 78650, 73700, 75400, 98670, 55440, 80850, 53640, 63250, 57690, 47790, 59000, 70600, 53280, 71760, 60390, 64350, 4730, 59900, 66780, 52700, 53400, 36720, 52800, 59100, 80740, 31350, 74280, 50400, 51810, 55660, 77660, 64800, 57860, 66600, 74200, 35900, 82800, 78100, 65520, 42700, 5580, 3600, 48950, 6120, 50800, 49950, 56430, 47700, 44880, 84480, 64800, 66880, 69680, 55170, 6400, 70400, 54810, 79800, 76230, 47760, 58300, 6490, 63800, 58160, 6300, 104610, 59670, 75400, 64100, 63580, 53820, 53730, 87960, 75570, 52400, 4700, 43280, 69000, 4620, 77330, 24570, 84100, 32280, 67770, 47400, 55000, 64200, 72400, 79970, 84590, 5000, 43700, 55000, 74700, 40700, 78980, 87890, 60500, 54360, 2860, 50800, 51920, 59400, 69930, 68750, 59400, 62880, 75400, 42700, 40260, 44440, 68760, 74400, 35300, 60190, 41580, 58500, 82610, 78600, 51390, 70200, 66480, 50380, 55400, 85900, 86130, 82170, 50300, 84500, 71610, 60600, 81240, 68200, 60750, 65560, 35860, 50050, 45540, 57240, 92730, 73260, 55200, 53100, 74800, 76400, 84920, 69080, 5940, 51370, 54960, 56160, 90860, 46800, 68200, 66900, 40810, 52650, 44200, 54400, 67300, 36740, 34160, 55200, 64300, 42680, 71190, 76010, 91520, 74690, 55000, 59400, 74360, 68240, 61050, 63600, 3900, 54200, 55400, 49100, 98280, 53280, 51900, 77000, 60320], "xaxis": "x", "y": [1406.91, 1197.22, 1415.74, 1351.1, 1301.13, 1131.4, 972.18, 1268.79, 1266.92, 848.07, 1337.28, 1334.15, 988.45, 1262.08, 1737.66, 1273.7, 795.23, 1848.81, 1641.73, 1362.87, 1239.22, 1105.49, 1055.53, 976.67, 769.95, 1226.83, 1136.83, 1690.27, 1352.83, 1125.37, 1338.5, 1074.07, 1298.91, 1110.37, 1103.58, 1625.45, 1394.43, 1352.31, 1139.0, 1277.25, 1238.62, 990.98, 1398.51, 1384.51, 847.03, 1158.03, 1053.04, 1275.39, 1166.54, 1587.96, 1079.92, 1382.88, 1054.83, 920.3, 1463.07, 768.91, 1217.69, 1362.64, 1279.13, 1314.6, 1649.18, 1053.02, 1371.78, 932.14, 1540.19, 1532.47, 1297.75, 1264.77, 1459.97, 1050.76, 1711.72, 1281.25, 1443.32, 1134.08, 1483.91, 1665.45, 1083.01, 1411.3, 694.45, 1348.32, 1407.01, 1194.0, 1366.9, 1090.65, 915.29, 1239.55, 1366.42, 1312.75, 765.64, 1454.42, 1252.08, 1379.93, 1554.64, 1313.33, 1085.03, 988.29, 1384.64, 904.7, 1030.95, 1609.67, 1618.65, 922.67, 1195.01, 994.74, 1050.24, 1185.78, 1554.86, 617.11, 1091.73, 1209.07, 1257.83, 1462.76, 1269.64, 1354.5, 1282.93, 949.44, 845.16, 814.96, 942.51, 1335.13, 1836.02, 1340.71, 1376.16, 1567.37, 1575.74, 1861.43, 1570.86, 791.47, 1012.78, 951.46, 1304.35, 1486.04, 1237.88, 1188.28, 1437.53, 1232.72, 1586.41, 1099.95, 1292.3, 1927.87, 1255.62, 1526.61, 1268.35, 1433.24, 945.73, 1317.97, 1285.09, 1537.07, 1757.87, 1430.8, 979.73, 1320.39, 1448.54, 995.7, 1202.28, 1358.03, 984.02, 1119.29, 1230.76, 625.08, 1133.27, 1307.68, 1520.78, 1295.87, 1543.68, 968.46, 1045. ...

# %%
fig=px.scatter_matrix(data,dimensions=['injury_claim', 'property_claim', 'vehicle_claim'],color = "fraud_reported")
fig.show()
# Out:
# <div>                            <div id="9a13e3a9-805a-4cf8-8efc-cb5e4b3bfeba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a13e3a9-805a-4cf8-8efc-cb5e4b3bfeba")) {                    Plotly.newPlot(                        "9a13e3a9-805a-4cf8-8efc-cb5e4b3bfeba",                        [{"dimensions": [{"axis": {"matches": true}, "label": "injury_claim", "values": [6510, 780, 6340, 6410, 4200, 10520, 17880, 8180, 16500, 1040, 7460, 10620, 6020, 10940, 16180, 6280, 15440, 11420, 6570, 13720, 13800, 12420, 6810, 14440, 5540, 0, 8940, 6630, 7210, 6650, 10860, 5540, 14000, 4770, 6400, 12760, 0, 10640, 4970, 13840, 7080, 7640, 12800, 8960, 17280, 9780, 9040, 0, 10790, 12960, 6700, 14880, 8060, 13440, 530, 5980, 9720, 6780, 7370, 12780, 11160, 12990, 5360, 14300, 7370, 7540, 15180, 5040, 7350, 5960, 5750, 6410, 5310, 5900, 7060, 11840, 11040, 10980, 5850, 860, 11980, 7420, 10540, 5340, 4080, 4800, 5910, 7340, 2850, 12380, 10080, 9420, 5060, 7060, 12960, 0, 16650, 14840, 7180, 20700, 15620, 9360, 0, 620, 360, 4450, 680, 10160, 5550, 6270, 4770, 8160, 7680, 6480, 6080, 8710, 6130, 640, 6400, 6090, 13300, 6930, 5970, 5830, 590, 6380, 7270, 630, 19020, 6630, 11600, 12820, 5780, 11960, 11940, 14660, 6870, 6550, 940, 0, 13800, 840, 14060, 2730, 16820, 5380, 7530, 9480, 5000, 6420, 7240, 7270, 7690, 500, 4370, 10000, 7470, 4070, 7180, 15980, 11000, 4530, 520, 5080, 9440, 6600, 0, 12500, 11880, 5240, 17400, 4270, 3660, 8080, 11460, 14880, 3530, 4630, 3780, 11700, 7510, 13100, 5710, 7020, 5540, 4580, 5540, 17180, 15660, 14940, 10060, 13000, 13020, 6060, 6770, 12400, 13500, 11920, 3260, 7700, 8280, 4770, 16860, 16280, 13800, 5310, 13600, 15280, 7720, 12560, 540, 9340, 6870, 6240, 12980, 4680, 13640, 6690, 3710, 5850, 4420, 5440, 6730, 3340, 0, 11040, 6430, 3880, 0, 13820, 8320, 6790, 10000, 13200, 13520, 8530, 11100, 5300, 390, 5420, 5540, 9820, 15120, 4440, 5190, 15400, 9280]}, {"axis": {"matches": true}, "label": "property_claim", "values": [13020, 780, 6340, 6410, 8400, 10520, 5960, 16360, 11000, 520, 7460, 5310, 6020, 10940, 16180, 6280, 0, 5710, 6570, 6860, 13800, 6210, 6810, 7220, 11080, 5640, 17880, 6630, 7210, 19950, 10860, 11080, 7000, 9540, 12800, 12760, 6160, 10640, 4970, 6920, 14160, 15280, 6400, 8960, 17280, 9780, 9040, 0, 21580, 12960, 6700, 7440, 16120, 6720, 530, 5980, 9720, 13560, 14740, 6390, 5580, 4330, 10720, 7150, 7370, 15080, 15180, 10080, 14700, 5960, 11500, 12820, 5310, 5900, 14120, 5920, 11040, 5490, 11700, 860, 5990, 7420, 10540, 5340, 4080, 9600, 5910, 14680, 5700, 12380, 5040, 4710, 10120, 14120, 6480, 10520, 11100, 14840, 3590, 13800, 7810, 9360, 6100, 620, 720, 8900, 680, 5080, 5550, 6270, 9540, 4080, 15360, 12960, 12160, 8710, 6130, 1280, 19200, 6090, 6650, 13860, 5970, 11660, 1180, 6380, 7270, 1260, 19020, 6630, 11600, 6410, 5780, 5980, 5970, 14660, 13740, 6550, 470, 5410, 6900, 840, 14060, 2730, 8410, 5380, 15060, 4740, 10000, 19260, 14480, 21810, 7690, 1000, 4370, 10000, 14940, 4070, 14360, 7990, 5500, 9060, 260, 5080, 4720, 13200, 15540, 12500, 5940, 10480, 11600, 4270, 7320, 4040, 5730, 7440, 3530, 9260, 7560, 0, 7510, 19650, 5710, 7020, 11080, 9160, 11080, 17180, 7830, 7470, 5030, 13000, 6510, 12120, 20310, 12400, 6750, 11920, 6520, 3850, 8280, 9540, 8430, 0, 9200, 5310, 6800, 7640, 15440, 6280, 1080, 4670, 0, 6240, 19470, 9360, 6820, 13380, 7420, 5850, 4420, 10880, 6730, 6680, 4270, 5520, 6430, 7760, 7910, 6910, 16640, 13580, 10000, 6600, 13520, 0, 11100, 10600, 780, 10840, 11080, 4910, 7560, 8880, 10380, 7700, 9280]}, {"axis": {"matches": true}, "label": "vehicle_claim", "values": [52080, 3510, 50720, 51280, 33600, 42080, 47680, 73620, 44000, 4160, 52220, 37170, 48160, 38290, 64720, 50240, 54040, 51390, 45990, 61740, 62100, 49680, 47670, 50540, 44320, 39480, 71520,  ...

# %%
import plotly_express as px

fig = px.scatter_matrix(data, dimensions=['months_as_customer', 'age','capital-gains'],color = "fraud_reported")
fig.show()
# Out:
# <div>                            <div id="f9ad375a-acf7-466b-a72e-4df3111bfc7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9ad375a-acf7-466b-a72e-4df3111bfc7d")) {                    Plotly.newPlot(                        "f9ad375a-acf7-466b-a72e-4df3111bfc7d",                        [{"dimensions": [{"axis": {"matches": true}, "label": "months_as_customer", "values": [328, 228, 256, 256, 180, 473, 370, 413, 8, 202, 166, 147, 62, 199, 116, 355, 154, 215, 295, 254, 107, 271, 222, 227, 284, 41, 61, 325, 29, 464, 298, 87, 453, 258, 225, 206, 203, 274, 81, 171, 22, 398, 214, 82, 193, 104, 101, 375, 112, 14, 119, 86, 125, 81, 196, 128, 11, 142, 272, 328, 246, 343, 27, 107, 177, 371, 269, 117, 111, 440, 20, 279, 134, 156, 232, 246, 332, 264, 108, 186, 436, 88, 39, 156, 175, 111, 151, 253, 10, 85, 97, 257, 78, 283, 290, 66, 216, 230, 270, 177, 451, 61, 283, 291, 162, 10, 140, 157, 113, 289, 157, 159, 437, 150, 4, 167, 310, 255, 152, 414, 123, 271, 448, 460, 245, 67, 380, 389, 317, 116, 19, 338, 405, 61, 184, 222, 15, 65, 478, 254, 313, 360, 364, 210, 272, 371, 402, 102, 222, 51, 463, 43, 152, 3, 64, 16, 255, 438, 206, 239, 330, 142, 140, 34, 183, 16, 128, 356, 252, 435, 344, 238, 313, 199, 186, 85, 162, 270, 168, 274, 152, 46, 276, 234, 456, 58, 96, 269, 39, 140, 243, 371, 175, 373, 258, 440, 264, 66, 335, 257, 119, 84, 421, 123, 110, 404, 250, 197, 97, 77, 9, 185, 297, 147, 427, 282, 218, 242, 80, 290, 195, 144, 121, 398, 115, 156, 121, 175, 231, 188, 211, 156, 136, 310, 154, 147, 279, 31, 163, 179, 232, 230, 234, 266, 230, 232, 235]}, {"axis": {"matches": true}, "label": "age", "values": [48, 42, 41, 39, 38, 58, 55, 55, 35, 34, 37, 33, 28, 37, 34, 47, 34, 42, 42, 39, 31, 42, 41, 38, 48, 25, 23, 47, 25, 61, 47, 31, 60, 46, 41, 36, 38, 43, 28, 34, 29, 58, 41, 27, 41, 32, 33, 50, 30, 28, 28, 26, 35, 25, 36, 32, 40, 33, 43, 46, 44, 52, 28, 26, 38, 51, 44, 28, 27, 61, 23, 43, 30, 31, 43, 45, 47, 41, 33, 33, 58, 25, 31, 37, 34, 29, 37, 41, 26, 30, 26, 40, 31, 46, 45, 26, 38, 39, 44, 33, 61, 24, 41, 46, 31, 19, 31, 32, 29, 46, 31, 33, 60, 31, 34, 36, 48, 44, 33, 52, 28, 44, 57, 57, 42, 29, 56, 53, 46, 30, 29, 47, 58, 26, 38, 39, 34, 23, 63, 40, 50, 51, 51, 35, 41, 54, 54, 32, 39, 34, 59, 43, 30, 29, 29, 35, 43, 57, 42, 39, 47, 29, 35, 34, 38, 32, 31, 54, 39, 60, 51, 43, 47, 38, 38, 31, 33, 41, 39, 45, 33, 41, 46, 44, 62, 23, 29, 41, 22, 32, 41, 50, 39, 55, 41, 57, 43, 30, 48, 40, 34, 32, 56, 29, 33, 56, 42, 41, 26, 26, 24, 34, 48, 37, 60, 43, 43, 44, 27, 45, 37, 37, 34, 55, 31, 38, 31, 36, 37, 33, 38, 32, 32, 48, 34, 31, 45, 32, 37, 32, 44, 37, 41, 42, 43, 42, 39]}, {"axis": {"matches": true}, "label": "capital-gains", "values": [53300, 0, 48900, 0, 41300, 55700, 72700, 0, 0, 31000, 27500, 53300, 0, 48500, 0, 0, 36900, 0, 62400, 35700, 43400, 56200, 37800, 0, 0, 0, 0, 61500, 0, 0, 28800, 0, 52600, 34400, 41200, 0, 0, 40700, 42400, 84900, 0, 0, 0, 13100, 0, 31900, 52000, 0, 47700, 0, 88800, 0, 0, 51000, 0, 0, 24000, 0, 0, 24800, 0, 0, 0, 40600, 0, 60300, 0, 47500, 0, 41500, 0, 0, 0, 0, 0, 34400, 91900, 55600, 0, 37600, 47400, 0, 0, 0, 82400, 0, 44000, 81300, 0, 51600, 0, 0, 0, 53500, 0, 0, 0, 68600, 47200, 0, 0, 47400, 60700, 0, 30700, 0, 59000, 0, 36100, 0, 40700, 69200, 48800, 52800, 0, 0, 0, 68500, 0, 44000, 38000, 0, 38600, 62500, 0, 60400, 66000, 0, 43700, 0, 0, 0, 0, 0, 0, 87800, 33500, 0, 47600, 0, 0, 0, 0, 0, 38600, 34700, 48000, 0, 71400, 0, 51700, 0, 58600, 0, 0, 59300, 75800, 0, 0, 44200, 0, 0, 0, 0, 20200, 50800, 0, 58500, 0, 73500, 0, 0, 63900, 0, 39300, 0, 45700, 62200, 0, 54700, 0, 43700, 0, 0, 82600, 57500, 47500, 0, 0, 0, 17300, 79600, 0, 0, 0, 51500, 0, 21100, 59900, 46100, 57100, 0, 49500, 64800, 0, 0, 69500, 0, 0, 49700, 51700, 0, 0, 0, 0, 75800, 61100, 0, 0, 38500, 0, 73700, 0,  ...

# %%
fig,ax=plt.subplots(4,3,figsize=(20,15))

i,j=0,0
for col in categ_index:
    if col in ['insured_occupation', 'insured_hobbies','auto_model','incident_city','auto_make','fraud_reported']:
        continue
    ax[i,j].pie(x=data[col].value_counts(), labels =list(data[col].value_counts().index), autopct='%.0f%%',radius=1,startangle=60)
    ax[i,j].set_title(col)
    j+=1
    if j==3:
        j=0
        i+=1

fig.tight_layout()
plt.show()

# %%
fig, axes = joypy.joyplot(data,
                         column = ['incident_hour_of_the_day','number_of_vehicles_involved', 'witnesses', 'bodily_injuries'],
                         by = 'incident_city',
                         ylim = 'own',
                         figsize = (15,8),
                         alpha = 0.5, 
                         legend = True)

plt.title('Incident hour, No. of vehicles, witnesses vs Incident City', fontsize = 20)
plt.show()

# %%
pd.crosstab(data['incident_state'], data['collision_type']).plot(kind='bar',figsize=(10,5))

# %%
pd.crosstab(data['incident_type'], data['authorities_contacted']).plot(kind='bar',figsize=(15,5))
plt.show()

# %%
pd.crosstab(data['policy_state'], data['fraud_reported']).sort_values('Y').plot(kind='bar',figsize=(10,5))
plt.show()

# %%
pd.crosstab(data['incident_state'], data['incident_severity']).sort_values('Total Loss').plot(kind='bar',figsize=(10,5))

# %% [markdown]
# ### Encoding the Features

# %%
categ_index
# Out:
# Index(['policy_state', 'policy_csl', 'insured_sex', 'insured_education_level',
#        'insured_occupation', 'insured_hobbies', 'insured_relationship',
#        'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'property_damage', 'police_report_available', 'auto_make', 'auto_model',
#        'fraud_reported'],
#       dtype='object')

# %%
# Mean Encoding --- policy_state, policy_csl ,insured_hobbies, insured_relationship ,collision_type,incident_state,incident_city,auto_make , auto_model
# Target guided ordinal Encoding --- insured_occupation , incident_severity , authorities_contacted
# One hot --- insured_sex , property damage,police_report_available , fraud reported
# Freq enc -- incident type
# Ordinal enc --- education level

# %%
# Explation for choosing the respective Encoding Methods

# We did fequency encoding for incident type because its frequency seemed to have a direct relation with the count of fraudulent autcomes
# Mean Encoding for the given columns cuz , those columns didn't have any ordinal order - so no ordinal enc ; have many unique categories - so one hot encoding would lead to 
#                                           curse of dimensionality ; their frequency didn't have any relation with the count of fraud outcomes
# One Hot Encoding - for all columns having only two categories
# Target Guided Ordinal Encoding - These features have some ordinal order , but we are not sure of it ; so we rank them in order of how well they predict the Target Variable

# %%
# One Hot Encoding

sex_map={'MALE':1,'FEMALE':0}
data.insured_sex=data.insured_sex.map(sex_map)

yes_no_map={'YES':1,"NO":0}
data.property_damage=data.property_damage.map(yes_no_map)

data.police_report_available=data.police_report_available.map(yes_no_map)

fraud_map={'Y':1,"N":0}
data.fraud_reported=data.fraud_reported.map(fraud_map)

# %%
# Mean Encoding 

policy_state_map=data.groupby(['policy_state'])['fraud_reported'].mean().to_dict()
# policy_state_map = { 'IL': 0.22781065088757396,'IN': 0.25483870967741934,'OH': 0.2585227272727273 }
data.policy_state=data.policy_state.map(policy_state_map)

policy_csl_map=data.groupby(['policy_csl'])['fraud_reported'].mean().to_dict()
# policy_csl_map={'100/300': 0.25787965616045844,'250/500': 0.2621082621082621,'500/1000': 0.21666666666666667}
data.policy_csl=data.policy_csl.map(policy_csl_map)

insured_hobby_map=data.groupby(['insured_hobbies'])['fraud_reported'].mean().to_dict()
#  insured_hobby_map={'base-jumping': 0.2653061224489796,'basketball': 0.17647058823529413,'board-games': 0.2916666666666667,'bungie-jumping': 0.16071428571428573,'camping': 0.09090909090909091,'chess': 0.8260869565217391,
#                       'cross-fit': 0.7428571428571429, 'dancing': 0.11627906976744186,'exercise': 0.19298245614035087,'golf': 0.10909090909090909,'hiking': 0.23076923076923078,'kayaking': 0.09259259259259259,
#                       'movies': 0.16363636363636364,'paintball': 0.22807017543859648,'polo': 0.2765957446808511,'reading': 0.265625,'skydiving': 0.22448979591836735,'sleeping': 0.1951219512195122,'video-games': 0.2,'yachting': 0.3018867924528302}
data.insured_hobbies=data.insured_hobbies.map(insured_hobby_map)

insured_relation_map=data.groupby(['insured_relationship'])['fraud_reported'].mean().to_dict()
# insured_relation_map={'husband': 0.20588235294117646,'not-in-family': 0.25862068965517243,'other-relative': 0.2937853107344633,'own-child': 0.21311475409836064,'unmarried': 0.24113475177304963,'wife': 0.2709677419354839}
data.insured_relationship=data.insured_relationship.map(insured_relation_map)

collision_map=data.groupby(['collision_type'])['fraud_reported'].mean().to_dict()
# collision_map={'Front Collision': 0.24605678233438485,'Rear Collision': 0.2774566473988439,'Side Collision': 0.2166172106824926}
data.collision_type=data.collision_type.map(collision_map)

incident_state_map=data.groupby(['incident_state'])['fraud_reported'].mean().to_dict()
# incident_state_map = {'NC': 0.3090909090909091,'NY': 0.22137404580152673,'OH': 0.43478260869565216,'PA': 0.26666666666666666,'SC': 0.29435483870967744,'VA': 0.22727272727272727,'WV': 0.17972350230414746}
data.incident_state=data.incident_state.map(incident_state_map)

incident_city_map=data.groupby(["incident_city"])['fraud_reported'].mean().to_dict()
# incident_city_map={'Arlington': 0.2894736842105263,'Columbus': 0.26174496644295303 ,'Hillsdale': 0.24822695035460993 ,'Northbend': 0.23448275862068965 ,'Northbrook': 0.22131147540983606, 'Riverwood': 0.22388059701492538,'Springfield': 0.24203821656050956}
data.incident_city=data.incident_city.map(incident_city_map)

auto_make_map=data.groupby(["auto_make"])['fraud_reported'].mean().to_dict()
# auto_make_map={'Accura': 0.19117647058823528,'Audi': 0.30434782608695654,'BMW': 0.2777777777777778,'Chevrolet': 0.27631578947368424,'Dodge': 0.25,'Ford': 0.3055555555555556,'Honda': 0.2545454545454545,'Jeep': 0.16417910447761194, 'Mercedes': 0.3384615384615385,'Nissan': 0.1794871794871795,'Saab': 0.225,'Suburu': 0.2375,'Toyota': 0.18571428571428572,'Volkswagen': 0.27941176470588236}
data.auto_make=data.auto_make.map(auto_make_map)

# we'll remove this column as it contains too many unique categ values---any manufactureer can have several models
auto_model_map=data.groupby(["auto_model"])['fraud_reported'].mean().to_dict()
data.auto_model=data.auto_model.map(auto_model_map)

# %%
# Target Guided Ordinal Encoding

occupation_map={j:i+5 for i,j in enumerate(data.groupby(["insured_occupation"])['fraud_reported'].mean().sort_values().index)}
# occupation_map={'other-service': 5,'priv-house-serv': 6,'adm-clerical': 7,'handlers-cleaners': 8,'prof-specialty': 9,'protective-serv': 10,'machine-op-inspct': 11,'armed-forces': 12,'sales': 13,
#                      'tech-support': 14,'transport-moving': 15,'craft-repair': 16,'farming-fishing': 17,'exec-managerial': 18}
data.insured_occupation=data.insured_occupation.map(occupation_map)

severity_map={j:i+5 for i,j in enumerate(data.groupby(["incident_severity"])['fraud_reported'].mean().sort_values().index)}
# severity_map={'Trivial Damage': 5, 'Minor Damage': 6, 'Total Loss': 7, 'Major Damage': 8}
data.incident_severity=data.incident_severity.map(severity_map)

authorities_map={j:i+5 for i,j in enumerate(data.groupby(["authorities_contacted"])['fraud_reported'].mean().sort_values().index)}
# authorities_map={'None': 5, 'Police': 6, 'Fire': 7, 'Ambulance': 8, 'Other': 9}
data.authorities_contacted=data.authorities_contacted.map(authorities_map)

# %%
# Freq encoding 

incident_type_map=data.incident_type.value_counts().to_dict()
data.incident_type=data.incident_type.map(incident_type_map)

# Ordinal encoding 

education_map={'High School':1,'College':2,'Associate':3,'Masters':4,'JD':5,'MD':6,'PhD':7}
data.insured_education_level=data.insured_education_level.map(education_map)

# %% [markdown]
# ### Removing Outliers

# %%
# Checking for Extreme Outliers in data

fig,ax=plt.subplots(5,3,figsize=(20,10))

i,j=0,0
for col in num_index:
    sns.boxplot(data[col],ax=ax[i,j],whis=3)
    j+=1
    if j==3:
        i+=1
        j=0

fig.tight_layout()

# %%
# It is clearly visible that we don't have any outliers at all
# Umbrella limit is showing outliers because most of the customers have 0 umbrella limit .
# However the values being shown as outliers in umbrella limit are important information , and not some random values
# There is just one outlier -- that is the negative umbrella limit value , that makes no sense whatsoever , so, we'll remove it

data.umbrella_limit.loc[data.umbrella_limit[data.umbrella_limit==-1000000].index[0]]=0
data.policy_annual_premium.loc[data.policy_annual_premium[data.policy_annual_premium==433.33].index[0]]=data.policy_annual_premium.mean()

# %% [markdown]
# ### Feature Extraction & Feature Selection

# %%
# Creating New Features

# claim_duration = policy_bind_date -incident_date 
# car_duration = auto_year - incident_date  

data['claim_duration']=(data['incident_date']-data['policy_bind_date']).dt.days
data['car_duration']=(data.incident_date-data.auto_year).dt.days

# Removing Unnecessary columns

data=data.drop(['incident_date','policy_bind_date','auto_year','auto_model'],axis=1)

# %%
# Feature Selection Methods

# Removing Highly Correlated Features
# Visualizing Pearsons Correlation Heatmap

plt.figure(figsize=(10,10))
sns.heatmap(data.drop(['fraud_reported'],axis=1).corr()) #method='spearman

# We can se that most of the features are not correlated ; which means they are independent

# %%
# Finding Higly Correlated Columns

def correlation(data,threshold):
    col_corr=set()
    cor=data.corr()
    for i in range(len(cor.columns)):
        for j in range(len(cor.columns)):
            if (abs(cor.iloc[i,j]) > threshold) and i!=j:
                if (cor.columns[j] in col_corr) or (cor.columns[i] in col_corr):
                    continue
                print("\n",cor.columns[i],"-----",cor.columns[j])
                print(abs(cor.iloc[i,j]))
                colname=cor.columns[i]
                col_corr.add(colname)
    return col_corr

a=correlation(data.drop(['fraud_reported'],axis=1),0.9)
print('\n',a)
# Out:
#  months_as_customer ----- age
# 0.9220983225789804
#
#  total_claim_amount ----- vehicle_claim
# 0.9827731790805634
#
#  {'months_as_customer', 'total_claim_amount'}

# %%
# Removing the higly correlated columns
data=data.drop(['age', 'total_claim_amount'],axis=1)
data.shape
# Out:
# (1000, 32)

# %%
# WRAPPER METHOD - SEQUENTIAL FEATURE SELECTOR

from sklearn.ensemble import RandomForestClassifier
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs

sfs=sfs(RandomForestClassifier(),k_features=20,forward=True,floating=False,scoring='recall',cv=3)
sfs.fit(data.drop(['fraud_reported'],axis=1),data.fraud_reported)
plot_sfs(sfs.get_metric_dict(),kind='std_dev')
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1b59b393610>)

# %%
sfs_support=[True if list(sfs.k_feature_names_).count(col)==1  else False for col in data.drop(['fraud_reported'],axis=1).columns ]
data.drop(['fraud_reported'],axis=1)[list(sfs.k_feature_names_)].columns
# Out:
# Index(['months_as_customer', 'policy_csl', 'policy_deductable', 'insured_sex',
#        'insured_education_level', 'insured_hobbies', 'insured_relationship',
#        'capital-loss', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_hour_of_the_day',
#        'property_damage', 'bodily_injuries', 'witnesses',
#        'police_report_available', 'property_claim', 'claim_duration'],
#       dtype='object')

# %%
# WRAPPER METHOD - RECURSIVE FEATURE ELIMINATION

from sklearn.feature_selection import chi2 , f_classif ,mutual_info_classif,RFE

rfe=RFE(RandomForestClassifier(),n_features_to_select=20)
rfe=rfe.fit(data.drop(['fraud_reported'],axis=1),data.fraud_reported)
rfe_support=rfe.get_support()
data.drop(['fraud_reported'],axis=1).columns[rfe_support]
# Out:
# Index(['months_as_customer', 'policy_annual_premium',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_severity', 'authorities_contacted', 'incident_state',
#        'incident_city', 'incident_hour_of_the_day', 'witnesses',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'claim_duration', 'car_duration'],
#       dtype='object')

# %%
# INTRINSIC FEATURE SELECTION - RANDOM FOREST

from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier

embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), max_features=20)
embeded_rf_selector.fit(data.drop(['fraud_reported'],axis=1),data.fraud_reported)
embeded_rf_support = embeded_rf_selector.get_support()
data.drop(['fraud_reported'],axis=1).columns[rfe_support]
# Out:
# Index(['months_as_customer', 'policy_annual_premium',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_severity', 'authorities_contacted', 'incident_state',
#        'incident_city', 'incident_hour_of_the_day', 'witnesses',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'claim_duration', 'car_duration'],
#       dtype='object')

# %%
# INTRINSIC FEATURE SELECTION - XGBOOST

from sklearn.feature_selection import SelectFromModel
from xgboost import XGBClassifier

xgb = SelectFromModel(XGBClassifier(use_label_encoder=False,eval_metric='error'), max_features=20)
xgb.fit(data.drop(['fraud_reported'],axis=1),data.fraud_reported)
xgb_support = xgb.get_support()
data.drop(['fraud_reported'],axis=1).columns[xgb_support]
# Out:
# Index(['umbrella_limit', 'insured_hobbies', 'incident_severity',
#        'property_damage'],
#       dtype='object')

# %%
# FILTER METHOD - CORRELATION

def cor_selector(X, y,num_feats):
    cor_list = []
    feature_name = X.columns.tolist()
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # feature name
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-num_feats:]].columns.tolist()
    # feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]
    return cor_support, cor_feature


cor_support, cor_feature = cor_selector(data.drop(['fraud_reported'],axis=1),data.fraud_reported,20)
data.drop(['fraud_reported'],axis=1).columns[cor_support]
# Out:
# Index(['policy_state', 'policy_csl', 'umbrella_limit', 'insured_occupation',
#        'insured_hobbies', 'insured_relationship', 'incident_type',
#        'collision_type', 'incident_severity', 'authorities_contacted',
#        'incident_state', 'incident_city', 'number_of_vehicles_involved',
#        'property_damage', 'bodily_injuries', 'witnesses', 'injury_claim',
#        'property_claim', 'vehicle_claim', 'auto_make'],
#       dtype='object')

# %%
# FILTER METHOD - CHI2

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import MinMaxScaler

X_norm = MinMaxScaler().fit_transform(data.drop(['fraud_reported'],axis=1))
chi_selector = SelectKBest(chi2, k=20)
chi_selector.fit(X_norm, data.fraud_reported)
chi_support = chi_selector.get_support()
data.drop(['fraud_reported'],axis=1).columns[chi_support]
# Out:
# Index(['policy_csl', 'umbrella_limit', 'insured_sex', 'insured_occupation',
#        'insured_hobbies', 'insured_relationship', 'incident_type',
#        'collision_type', 'incident_severity', 'authorities_contacted',
#        'incident_state', 'incident_city', 'number_of_vehicles_involved',
#        'property_damage', 'bodily_injuries', 'witnesses', 'injury_claim',
#        'property_claim', 'vehicle_claim', 'auto_make'],
#       dtype='object')

# %%
feature_selection=pd.DataFrame(data={'Features':data.drop(['fraud_reported'],axis=1).columns,"Person_corr":cor_support,'CHI2':chi_support,
                                                        "SFS":sfs_support,'RFE':rfe_support,'Rand-Forest':embeded_rf_support,"XGB":xgb_support})
feature_selection['Total'] = np.sum(feature_selection, axis=1)

feature_selection_df = feature_selection.sort_values(['Total'] , ascending=False)
feature_selection_df.index = range(1, len(feature_selection_df)+1)
feature_selection_df
# Out:
#                        Features  Person_corr   CHI2    SFS    RFE  \
# 1             incident_severity         True   True   True   True
# 2               insured_hobbies         True   True   True   True
# 3                property_claim         True   True   True   True
# 4         authorities_contacted         True   True   True   True
# 5                 vehicle_claim         True   True  False   True
# 6                  injury_claim         True   True  False   True
# 7                     witnesses         True   True   True   True
# 8            insured_occupation         True   True  False   True
# 9          insured_relationship         True   True   True   True
# 10              property_damage         True   True   True  False
# 11               incident_state         True   True   True   True
# 12               claim_duration        False  False   True   True
# 13                    auto_make         True   True  False   True
# 14              bodily_injuries         True   True   True  False
# 15                incident_city         True   True  False   True
# 16           months_as_customer        False  False   True   True
# 17               collision_type         True   True   True  False
# 18                incident_type         True   True   True  False
# 19               umbrella_limit         True   True  False  False
# 20                   policy_csl         True   True   True  False
# 21     incident_hour_of_the_day        False  False   True   True
# 22  number_of_vehicles_involved         True   True  False  False
# 23                 capital-loss        False  False   True   True
# 24      insured_education_level        False  False   True   True
# 25                  insured_sex        False   True   True  False
# 26        policy_annual_premium        False  False  False   True
# 27                 car_duration        False  False  False   True
# 28                 policy_state         True  False  False  False
# 29                capital-gains        False  False  False   True
# 30      police_report_available        False  False   True  False
# 31            policy_deductable        False  False   True  False
#
#     Rand-Forest    XGB  Total
# 1          True   True      6
# 2          True   True      6
# 3          True  False      5
# 4         False  False      4
# 5          True  False      4
# 6          True  False      4
# 7         False  False      4
# 8          True  False      4
# 9         False  False      4
# 10        False   True      4
# 11        False  False      4
# 12         True  False      3
# 13        False  False      3
# 14        False  False      3
# 15        False  False      3
# 16         True  False      3
# 17        False  False      3
# 18        False  False      3
# 19        False   True      3
# 20        False  False      3
# 21        False  False      2
# 22        False  False      2
# 23        False  False      2
# 24        False  False      2
# 25        False  False      2
# 26         True  False      2
# 27         True  False      2
# 28        False  False      1
# 29        False  False      1
# 30        False  False      1
# 31        False  False      1

# %%
# We take the top 20 features

feature_selection_df.loc[:20,'Features'].values
# Out:
# array(['incident_severity', 'insured_hobbies', 'property_claim',
#        'authorities_contacted', 'vehicle_claim', 'injury_claim',
#        'witnesses', 'insured_occupation', 'insured_relationship',
#        'property_damage', 'incident_state', 'claim_duration', 'auto_make',
#        'bodily_injuries', 'incident_city', 'months_as_customer',
#        'collision_type', 'incident_type', 'umbrella_limit', 'policy_csl'],
#       dtype=object)

# %%
# Reordering Data

data=data[[ 'incident_type','collision_type','incident_severity', 'auto_make','incident_state', 'incident_city', 'authorities_contacted','witnesses','bodily_injuries',
              'property_claim','vehicle_claim', 'injury_claim','property_damage',  'claim_duration',
              'months_as_customer', 'policy_csl','umbrella_limit',
              'insured_occupation', 'insured_relationship','insured_hobbies','fraud_reported']]

# %%
# Checking for Imbalance

fig=plt.figure(figsize=(8,5))
sns.countplot(data.fraud_reported)

# %%
from imblearn.over_sampling import SMOTE

X=data.drop(['fraud_reported'],axis=1)
y=data['fraud_reported']
smote=SMOTE(k_neighbors=10,sampling_strategy='minority')
X,y=smote.fit_resample(X,y)

# %%
data=pd.merge(X,y,left_index=True,right_index=True)
data
# Out:
#       incident_type  collision_type  incident_severity  auto_make  \
# 0               403        0.217514                  8   0.225000
# 1                94        0.217514                  6   0.338462
# 2               419        0.274286                  6   0.250000
# 3               403        0.250000                  8   0.276316
# 4                94        0.217514                  6   0.191176
# ...             ...             ...                ...        ...
# 1501            406        0.274286                  8   0.256114
# 1502            404        0.250000                  7   0.275936
# 1503            403        0.274176                  7   0.225246
# 1504            404        0.246498                  7   0.187088
# 1505            409        0.274286                  8   0.301829
#
#       incident_state  incident_city  authorities_contacted  witnesses  \
# 0           0.294355       0.261745                      6          2
# 1           0.227273       0.223881                      6          0
# 2           0.221374       0.261745                      6          3
# 3           0.434783       0.289474                      6          2
# 4           0.221374       0.289474                      5          1
# ...              ...            ...                    ...        ...
# 1501        0.221374       0.242038                      6          1
# 1502        0.289516       0.228230                      7          2
# 1503        0.180307       0.248105                      8          2
# 1504        0.216884       0.227962                      8          2
# 1505        0.224935       0.248227                      7          2
#
#       bodily_injuries  property_claim  vehicle_claim  injury_claim  \
# 0                   1           13020          52080          6510
# 1                   0             780           3510           780
# 2                   2            3850          23100          7700
# 3                   1            6340          50720          6340
# 4                   0             650           4550          1300
# ...               ...             ...            ...           ...
# 1501                1            5306          49745         14213
# 1502                2            7915          63775         15830
# 1503                2            6395          51130         12791
# 1504                1           11826          40679          5913
# 1505                1            5431          27322          3415
#
#       property_damage  claim_duration  months_as_customer  policy_csl  \
# 0                   1             100                 328    0.262108
# 1                   1            3130                 228    0.262108
# 2                   0            5282                 134    0.257880
# 3                   0            8996                 256    0.262108
# 4                   0             256                 228    0.216667
# ...               ...             ...                 ...         ...
# 1501                0            7138                 167    0.261122
# 1502                0            8826                 239    0.261828
# 1503                0            6822                 327    0.216667
# 1504                1            6121                 412    0.257880
# 1505                0            8674                 304    0.262108
#
#       umbrella_limit  insured_occupation  insured_relationship  \
# 0                  0                  16              0.205882
# 1            5000000                  11              0.293785
# 2            5000000                  13              0.213115
# 3            6000000                  12              0.241135
# 4            6000000                  13              0.241135
# ...              ...                 ...                   ...
# 1501               0                  16              0.293785
# 1502               0                  10              0.272481
# 1503               0                   9              0.258621
# 1504               0                  15              0.211567
# 1505               0                  17              0.280011
#
#       insured_hobbies  fraud_reported
# 0            0.195122               1
# 1            0.265625               1
# 2            0.291667               0
# 3            0.291667               1
# 4            0.291667               0
# ...               ...             ...
# 1501         0.293358               1
# 1502         0.270242               1
# 1503         0.192908               1
# 1504         0.289339               1
# 1505         0.240667               1
#
# [1506 rows x 21 columns]

# %%
fig=plt.figure(figsize=(8,5))
sns.countplot(data.fraud_reported)

# %% [markdown]
# ### Clustering

# %%
# Elbow curve ,to determine optimal no. of clusters
# Clustering data to fit separate models on the different clusters , to check if  model generalises better after clustering , or as a whole

from sklearn.cluster import dbscan,KMeans

inertia=[]
for k in range(2,10):
    cluster=KMeans(n_clusters=k,n_init=10)
    cluster.fit(data)
    inertia.append(cluster.inertia_)

elbow=pd.DataFrame(data={'Cluster':range(2,10),'Inertia':inertia})
sns.lineplot(x=elbow.Cluster,y=elbow.Inertia)

# %%
#From above elbow curve , optimal no. of clusters is 4 

from sklearn.cluster import KMeans

kmeans=KMeans(n_clusters=4)
kmeans.fit(data.drop(['fraud_reported'],axis=1)) 
data['Cluster']=kmeans.predict(data.drop(['fraud_reported'],axis=1))
data.head()
# Out:
#    incident_type  collision_type  incident_severity  auto_make  \
# 0            403        0.217514                  8   0.225000
# 1             94        0.217514                  6   0.338462
# 2            419        0.274286                  6   0.250000
# 3            403        0.250000                  8   0.276316
# 4             94        0.217514                  6   0.191176
#
#    incident_state  incident_city  authorities_contacted  witnesses  \
# 0        0.294355       0.261745                      6          2
# 1        0.227273       0.223881                      6          0
# 2        0.221374       0.261745                      6          3
# 3        0.434783       0.289474                      6          2
# 4        0.221374       0.289474                      5          1
#
#    bodily_injuries  property_claim  vehicle_claim  injury_claim  \
# 0                1           13020          52080          6510
# 1                0             780           3510           780
# 2                2            3850          23100          7700
# 3                1            6340          50720          6340
# 4                0             650           4550          1300
#
#    property_damage  claim_duration  months_as_customer  policy_csl  \
# 0                1             100                 328    0.262108
# 1                1            3130                 228    0.262108
# 2                0            5282                 134    0.257880
# 3                0            8996                 256    0.262108
# 4                0             256                 228    0.216667
#
#    umbrella_limit  insured_occupation  insured_relationship  insured_hobbies  \
# 0               0                  16              0.205882         0.195122
# 1         5000000                  11              0.293785         0.265625
# 2         5000000                  13              0.213115         0.291667
# 3         6000000                  12              0.241135         0.291667
# 4         6000000                  13              0.241135         0.291667
#
#    fraud_reported  Cluster
# 0               1        1
# 1               1        3
# 2               0        3
# 3               1        3
# 4               0        3

# %%
# cluster labels
set(kmeans.labels_)
# Out:
# {0, 1, 2, 3}

# %%
data.Cluster.value_counts()
# Out:
# 1    1197
# 3     160
# 2      88
# 0      61
# Name: Cluster, dtype: int64

# %%
data_c1=data[data.Cluster==0].drop(['Cluster'],axis=1).copy(deep=True)
data_c2=data[data.Cluster==1].drop(['Cluster'],axis=1).copy(deep=True)
data_c3=data[data.Cluster==2].drop(['Cluster'],axis=1).copy(deep=True)
data_c4=data[data.Cluster==3].drop(['Cluster'],axis=1).copy(deep=True)

# %%
data=data.drop(['Cluster'],axis=1)

# %%
#Classification Models to try :
""" Logistic Regression , KNN , SVM , Naive Bayes Classifier , Dtree Classifier, XGB classifier , rand-forest classifier,Stacking """

# %%
# Evaluation metric for models -Recall ( Since , it is important to classify all frauds as frauds , else the company will ncur huge losses )
# From the Company's point of view , it is much reasonable to choose Recall as metric
# From the customers point of view , it is easonable to choose Precision -- since we want to see - how trustable the model in terms of predicting fraud (Out of the predicted frauds , how many are actually frauds)

# %%
#Trying Logistic Regression

import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import recall_score,accuracy_score,roc_auc_score
from sklearn.model_selection import cross_val_score , RepeatedStratifiedKFold

scores_logreg=[]
accuracy_logreg=[]

# Standardizing the data

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

for i in [data,data_c1,data_c2,data_c3,data_c4]:
        X=i.drop(['fraud_reported'],axis=1)
        X=scaler.fit_transform(X)
        y=i.fraud_reported

        logreg=LogisticRegression(max_iter=1000,solver='newton-cg')
        cv=RepeatedStratifiedKFold(n_splits=10, n_repeats=5,random_state=1)

        #collecting recall
        recall=cross_val_score(logreg,X,y,cv=cv,scoring='recall')
        scores_logreg.append(recall.mean())
        
        #collecting accuracy
        acc=cross_val_score(logreg,X,y,cv=cv,scoring='accuracy')
        accuracy_logreg.append(acc.mean())
        
print(f"Entire Data--Recall:{scores_logreg[0]}  Accuracy :{accuracy_logreg[0]} ") 
print(f"Cluster 1--Recall:{scores_logreg[1]}  Accuracy :{accuracy_logreg[1]} ")
print(f"Cluster 2--Recall:{scores_logreg[2]}  Accuracy :{accuracy_logreg[2]} ")
print(f"Cluster 3--Recall:{scores_logreg[3]}  Accuracy :{accuracy_logreg[3]} ")
print(f"Cluster 4--Recall:{scores_logreg[4]}  Accuracy :{accuracy_logreg[4]} ")
# Out:
# Entire Data--Recall:0.8334491228070177  Accuracy :0.8222878587196467
# Cluster 1--Recall:0.9516666666666667  Accuracy :0.8747619047619049
# Cluster 2--Recall:0.8177498538866159  Accuracy :0.8110154061624648
# Cluster 3--Recall:0.9533333333333333  Accuracy :0.8419444444444443
# Cluster 4--Recall:0.9158333333333334  Accuracy :0.88625

# %%
# Trying KNN Classifier

from sklearn.neighbors import KNeighborsClassifier

scores_knn=[]
accuracy_knn=[]

scaler=StandardScaler()

for i in [data,data_c1,data_c2,data_c3,data_c4]:
        X=i.drop(['fraud_reported'],axis=1)
        X=scaler.fit_transform(X)
        y=i.fraud_reported
        
        knn=KNeighborsClassifier(n_neighbors=10,weights='distance',metric='euclidean')
        cv=RepeatedStratifiedKFold(n_splits=10, n_repeats=5,random_state=1)

        #collecting recall
        recall=cross_val_score(knn,X,y,cv=cv,scoring='recall')
        scores_knn.append(recall.mean())
        
        #collecting accuracy
        acc=cross_val_score(knn,X,y,cv=cv,scoring='accuracy')
        accuracy_knn.append(acc.mean())
            
print(f"Entire Data : {scores_knn[0]}  Accuracy : {accuracy_knn[0]}")
print(f"Cluster 1---Recall : {scores_knn[1]}  Accuracy : {accuracy_knn[1]}")
print(f"Cluster 2---Recall : {scores_knn[2]}  Accuracy : {accuracy_knn[2]}")
print(f"Cluster 3---Recall : {scores_knn[3]}  Accuracy : {accuracy_knn[3]}")
print(f"Cluster 4---Recall : {scores_knn[4]}  Accuracy : {accuracy_knn[4]}")
# Out:
# Entire Data : 0.9734491228070177  Accuracy : 0.7998657836644592
# Cluster 1---Recall : 0.9733333333333333  Accuracy : 0.7790476190476191
# Cluster 2---Recall : 0.97947983635301  Accuracy : 0.7983375350140054
# Cluster 3---Recall : 0.9880000000000001  Accuracy : 0.7227777777777777
# Cluster 4---Recall : 0.9605555555555557  Accuracy : 0.8175

# %%
# Trying SVM Classifier

from sklearn.svm import SVC,LinearSVC

scores_svc=[]
accuracy_svc=[]

scaler=StandardScaler()

for i in [data,data_c1,data_c2,data_c3,data_c4]:
        X=i.drop(['fraud_reported'],axis=1)
        X=scaler.fit_transform(X)
        y=i.fraud_reported
        
        svc=SVC(C=1, kernel="poly", degree=4)
        cv=RepeatedStratifiedKFold(n_splits=10, n_repeats=5,random_state=1)

        #collecting recall
        recall=cross_val_score(svc,X,y,cv=cv,scoring='recall')
        scores_svc.append(recall.mean())
        
        #collecting accuracy
        acc=cross_val_score(svc,X,y,cv=cv,scoring='accuracy')
        accuracy_svc.append(acc.mean())
            
print(f"Entire Data : {scores_svc[0]}  Accuracy : {accuracy_svc[0]}")
print(f"Cluster 1---Recall : {scores_svc[1]}  Accuracy : {accuracy_svc[1]}")
print(f"Cluster 2---Recall : {scores_svc[2]}  Accuracy : {accuracy_svc[2]}")
print(f"Cluster 3---Recall : {scores_svc[3]}  Accuracy : {accuracy_svc[3]}")
print(f"Cluster 4---Recall : {scores_svc[4]}  Accuracy : {accuracy_svc[4]}")
# Out:
# Entire Data : 0.9487368421052631  Accuracy : 0.7658772626931567
# Cluster 1---Recall : 0.9816666666666666  Accuracy : 0.6128571428571429
# Cluster 2---Recall : 0.95656341320865  Accuracy : 0.7578837535014006
# Cluster 3---Recall : 1.0  Accuracy : 0.6075
# Cluster 4---Recall : 0.9716666666666667  Accuracy : 0.68875

# %%
# Trying Naive Bayes

from sklearn.naive_bayes import MultinomialNB , GaussianNB

scores_nb=[]
accuracy_nb=[]

for i in [data,data_c1,data_c2,data_c3,data_c4]:
        X=i.drop(['fraud_reported'],axis=1)
        X=scaler.fit_transform(X)
        y=i.fraud_reported
        
        nb=GaussianNB()
        cv=RepeatedStratifiedKFold(n_splits=10, n_repeats=5,random_state=1)

        #collecting recall
        recall=cross_val_score(nb,X,y,cv=cv,scoring='recall')
        scores_nb.append(recall.mean())
        
        #collecting accuracy
        acc=cross_val_score(nb,X,y,cv=cv,scoring='accuracy')
        accuracy_nb.append(acc.mean())

print(f"Entire Data : {scores_nb[0]}  Accuracy : {accuracy_nb[0]}")   
print(f"Cluster 1---Recall : {scores_nb[1]}  Accuracy : {accuracy_nb[1]}")
print(f"Cluster 2---Recall : {scores_nb[2]}  Accuracy : {accuracy_nb[2]}")
print(f"Cluster 3---Recall : {scores_nb[3]}  Accuracy : {accuracy_nb[3]}")
print(f"Cluster 4---Recall : {scores_nb[4]}  Accuracy : {accuracy_nb[4]}")
# Out:
# Entire Data : 0.9030350877192983  Accuracy : 0.7723558498896247
# Cluster 1---Recall : 0.8583333333333333  Accuracy : 0.7866666666666666
# Cluster 2---Recall : 0.1100116890707189  Accuracy : 0.5555546218487395
# Cluster 3---Recall : 0.796  Accuracy : 0.7444444444444445
# Cluster 4---Recall : 0.8880555555555556  Accuracy : 0.79875

# %%
#Trying Random Forest

from sklearn.ensemble import RandomForestClassifier

scores_rf=[]
accuracy_rf=[]

for i in [data,data_c1,data_c2,data_c3,data_c4]:
        X=i.drop(['fraud_reported'],axis=1)
        y=i.fraud_reported
        
        rf=RandomForestClassifier()
        cv=RepeatedStratifiedKFold(n_splits=10, n_repeats=5,random_state=1)

        #collecting recall
        recall=cross_val_score(rf,X,y,cv=cv,scoring='recall')
        scores_rf.append(recall.mean())
        
        #collecting accuracy
        acc=cross_val_score(rf,X,y,cv=cv,scoring='accuracy')
        accuracy_rf.append(acc.mean())

print(f"Entire Data : {scores_rf[0]}  Accuracy : {accuracy_rf[0]}")
print(f"Cluster 1---Recall : {scores_rf[1]}  Accuracy : {accuracy_rf[1]}")
print(f"Cluster 2---Recall : {scores_rf[2]}  Accuracy : {accuracy_rf[2]}")
print(f"Cluster 3---Recall : {scores_rf[3]}  Accuracy : {accuracy_rf[3]}")
print(f"Cluster 4---Recall : {scores_rf[4]}  Accuracy : {accuracy_rf[4]}")
# Out:
# Entire Data : 0.9115754385964913  Accuracy : 0.898787637969095
# Cluster 1---Recall : 0.8383333333333333  Accuracy : 0.842857142857143
# Cluster 2---Recall : 0.8997895967270603  Accuracy : 0.896718487394958
# Cluster 3---Recall : 0.922  Accuracy : 0.8636111111111111
# Cluster 4---Recall : 0.8994444444444446  Accuracy : 0.89125

# %%
#Trying XGB Classsifier

from xgboost import XGBClassifier

scores_xgb=[]
accuracy_xgb=[]

for i in [data,data_c1,data_c2,data_c3,data_c4]:
        X=i.drop(['fraud_reported'],axis=1)
        y=i.fraud_reported
        X_train,X_test,y_train,y_test=train_test_split(X,np.ravel(y),test_size=0.3,random_state=2)
        
        xgb=XGBClassifier(use_label_encoder=False ,eval_metric='error')
        cv=RepeatedStratifiedKFold(n_splits=10, n_repeats=3,random_state=1)

        #collecting recall
        recall=cross_val_score(xgb,X,y,cv=cv,scoring='recall')
        scores_xgb.append(recall.mean())
        
        #collecting accuracy
        acc=cross_val_score(xgb,X,y,cv=cv,scoring='accuracy')
        accuracy_xgb.append(acc.mean())
            
print(f"Entire Data : {scores_xgb[0]}  Accuracy : {accuracy_xgb[0]}")
print(f"Cluster 1---Recall : {scores_xgb[1]}  Accuracy : {accuracy_xgb[1]}")
print(f"Cluster 2---Recall : {scores_xgb[2]}  Accuracy : {accuracy_xgb[2]}")
print(f"Cluster 3---Recall : {scores_xgb[3]}  Accuracy : {accuracy_xgb[3]}")
print(f"Cluster 4---Recall : {scores_xgb[4]}  Accuracy : {accuracy_xgb[4]}")
# Out:
# Entire Data : 0.9127134502923977  Accuracy : 0.9023782192788815
# Cluster 1---Recall : 0.7805555555555557  Accuracy : 0.7817460317460317
# Cluster 2---Recall : 0.9093415156828365  Accuracy : 0.8992063492063491
# Cluster 3---Recall : 0.9733333333333333  Accuracy : 0.9078703703703703
# Cluster 4---Recall : 0.9222222222222222  Accuracy : 0.8895833333333333

# %%
# Comparing Recall Values

recall_vals=pd.DataFrame(data=[scores_logreg,scores_knn,scores_svc,
                        scores_nb,scores_rf,scores_xgb],
                        index=['Logreg_recall','knn_recall','svc_recall',
                        'nb_recall','rf_recall','xgb_recall'],
                        columns=['Entire Data','Cluster 1','Cluster 2','Cluster 3','Cluster 4'])

recall_vals
# Out:
#                Entire Data  Cluster 1  Cluster 2  Cluster 3  Cluster 4
# Logreg_recall     0.833449   0.951667   0.817750   0.953333   0.915833
# knn_recall        0.973449   0.973333   0.979480   0.988000   0.960556
# svc_recall        0.948737   0.981667   0.956563   1.000000   0.971667
# nb_recall         0.903035   0.858333   0.110012   0.796000   0.888056
# rf_recall         0.911575   0.838333   0.899790   0.922000   0.899444
# xgb_recall        0.912713   0.780556   0.909342   0.973333   0.922222

# %%
# Comparing Accuracy Values

accuracy_vals=pd.DataFrame(data=[accuracy_logreg,accuracy_knn,accuracy_svc,
                        accuracy_nb,accuracy_rf,accuracy_xgb],
                        index=['Logreg_accuracy','knn_accuracy','svc_accuracy',
                        'nb_accuracy','rf_accuracy','xgb_accuracy'],
                        columns=['Entire Data','Cluster 1','Cluster 2','Cluster 3','Cluster 4'])

accuracy_vals
# Out:
#                  Entire Data  Cluster 1  Cluster 2  Cluster 3  Cluster 4
# Logreg_accuracy     0.822288   0.874762   0.811015   0.841944   0.886250
# knn_accuracy        0.799866   0.779048   0.798338   0.722778   0.817500
# svc_accuracy        0.765877   0.612857   0.757884   0.607500   0.688750
# nb_accuracy         0.772356   0.786667   0.555555   0.744444   0.798750
# rf_accuracy         0.898788   0.842857   0.896718   0.863611   0.891250
# xgb_accuracy        0.902378   0.781746   0.899206   0.907870   0.889583

# %%
for i in recall_vals.columns:
    print(f"Best Model for {i} : {recall_vals[i].idxmax()} ")
# Out:
# Best Model for Entire Data : knn_recall
# Best Model for Cluster 1 : svc_recall
# Best Model for Cluster 2 : knn_recall
# Best Model for Cluster 3 : svc_recall
# Best Model for Cluster 4 : svc_recall

# %%
for i in accuracy_vals.columns:
    print(f"Best Model for {i} : {accuracy_vals[i].idxmax()} ")
# Out:
# Best Model for Entire Data : xgb_accuracy
# Best Model for Cluster 1 : Logreg_accuracy
# Best Model for Cluster 2 : xgb_accuracy
# Best Model for Cluster 3 : xgb_accuracy
# Best Model for Cluster 4 : rf_accuracy
